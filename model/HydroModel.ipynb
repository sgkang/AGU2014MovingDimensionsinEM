# %%
from SimPEG import *
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cs, ncx, ncy, ncz, npad = 20., 30, 20, 30, 12
hx = [(cs,npad,-1.4), (cs,ncx), (cs,npad,1.4)]
hy = [(cs,npad,-1.4), (cs,ncy), (cs,npad,1.4)]
hz = [(cs,npad,-1.4), (cs,ncz), (cs,npad,1.4)]
mesh = Mesh.TensorMesh([hx,hy,hz], 'CCC')
print ("Padding distance x: %10.5f m") % (np.sum(mesh.hx[:npad]))
print ("Padding distance z: %10.5f m") % (np.sum(mesh.hz[:npad]))
print ("Min dx: %10.5f m") % (mesh.hx.min())
print ("Min dz: %10.5f m") % (mesh.hz.min())
# Out:
# Padding distance x: 3898.57387 m
# Padding distance z: 3898.57387 m
# Min dx:   20.00000 m
# Min dz:   20.00000 m

# %%
print mesh
# Out:
#   ---- 3-D TensorMesh ----
#    x0: -4198.57
#    y0: -4098.57
#    z0: -4198.57
#   nCx: 54
#   nCy: 44
#   nCz: 54
#    hx: 1133.88, 809.91, 578.51, 413.22, 295.16, 210.83, 150.59, 107.56, 76.83, 54.88, 39.20, 28.00, 30*20.00, 28.00, 39.20, 54.88, 76.83, 107.56, 150.59, 210.83, 295.16, 413.22, 578.51, 809.91, 1133.88
#    hy: 1133.88, 809.91, 578.51, 413.22, 295.16, 210.83, 150.59, 107.56, 76.83, 54.88, 39.20, 28.00, 20*20.00, 28.00, 39.20, 54.88, 76.83, 107.56, 150.59, 210.83, 295.16, 413.22, 578.51, 809.91, 1133.88
#    hz: 1133.88, 809.91, 578.51, 413.22, 295.16, 210.83, 150.59, 107.56, 76.83, 54.88, 39.20, 28.00, 30*20.00, 28.00, 39.20, 54.88, 76.83, 107.56, 150.59, 210.83, 295.16, 413.22, 578.51, 809.91, 1133.88

# %%
def circfun(xc, yc, r, npoint):
    theta = np.linspace(np.pi, -np.pi, npoint)
    x = r*np.cos(theta)
    y = r*np.sin(theta)
    return x+xc, y+yc

# %%
xcirc1, ycirc1 = circfun(-150., 0., 250., 60)
xcirc2, ycirc2 = circfun(150., 0., 250., 60)

# %%
Utils.meshutils.writeUBCTensorMesh(mesh, 'mesh.msh')

# %%
sigma = Utils.meshutils.readUBCTensorModel('sigma.con', mesh)

# %%
x1 = np.arange(30)*10 - 300.
y1 = np.arange(30)*10 - 150.
xyz1 = Utils.ndgrid(x1, y1, np.r_[0.])
x2 = np.arange(30)*10 + 10.
y2 = np.arange(30)*10 - 150.
xyz2 = Utils.ndgrid(x2, y2, np.r_[0.])

# %%
fig, ax = plt.subplots(1,1, figsize=(6,6))
mesh.plotSlice(np.log10(sigma), ind = 20, ax = ax)
plt.plot(xyz1[:,0], xyz1[:,1], 'r.')
plt.plot(xyz2[:,0], xyz2[:,1], 'b.')
plt.plot(xcirc1, ycirc1, 'r-')
plt.plot(xcirc2, ycirc2, 'b-')
xlim(-400, 400)
ylim(-400, 400)
# Out:
# (-400, 400)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,4))
dat = mesh.plotSlice(np.log10(sigma), normal='Y', ind = 25, ax = ax, clim=(-3, -1))
xlim(-400, 400)
ylim(-400, 0.)
plt.colorbar(dat[0], ax = ax)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x000000000A733148>

# %%
import simpegEM as EM
mapping = Maps.IdentityMap(mesh)

# %%
ntx = 2
nrx1 = xyz1.shape[0]
time = np.logspace(-4, -2, 31)

# %%
print time
# Out:
# [ 0.0001      0.00011659  0.00013594  0.00015849  0.00018478  0.00021544
#   0.00025119  0.00029286  0.00034145  0.00039811  0.00046416  0.00054117
#   0.00063096  0.00073564  0.0008577   0.001       0.00116591  0.00135936
#   0.00158489  0.00184785  0.00215443  0.00251189  0.00292864  0.00341455
#   0.00398107  0.00464159  0.0054117   0.00630957  0.00735642  0.00857696
#   0.01      ]

# %%
rx1 = EM.TDEM.RxTDEM(xyz1, time, 'bz')
tx1 = EM.TDEM.TxTDEM(np.array([0., -150., 0.]), 'CircularLoop_MVP', [rx1])
tx1.radius = 250.
rx2 = EM.TDEM.RxTDEM(xyz2, time, 'bz')
tx2 = EM.TDEM.TxTDEM(np.array([0.,  150., 0.]), 'CircularLoop_MVP', [rx2])
tx2.radius = 250.

# %%
# survey = EM.TDEM.SurveyTDEM([tx1, tx2])
survey = EM.TDEM.SurveyTDEM([tx1])
prb = EM.TDEM.ProblemTDEM_b(mesh, mapping=mapping, verbose=True)
# prb.solver = MumpsSolver
# prb.solverOpts = {"symmetric":True}
# prb.timeSteps = [(1e-4/15, 10), (1e-3/15, 10), (1e-2/15, 5)]
prb.timeSteps = [(1e-4/15, 10)]
if prb.ispaired:
    prb.unpair()
if survey.ispaired:
    survey.unpair()
prb.pair(survey)

# %%
dpred = np.load('../codes/bz.npy')

# %%
noise = abs(dpred)*np.random.randn(dpred.size)*0.05 
dobs = dpred+noise

# %%
print dpred.shape
# Out:
# (55800L,)

# %%
Dpred = dobs.reshape((900, 31, 2), order='F')
Dpred1 = Dpred[:,:,0]
Dpred2 = Dpred[:,:,1]

# %%
itime = 30
fig, ax = plt.subplots(1,2, figsize = (12, 5))
for i in range(2):
    ax[i].set_xlabel('x (m)', fontsize = 16)
    ax[i].set_ylabel('y (m)', fontsize = 16)
dat1 = ax[0].contourf(xyz1[:,0].reshape((30, 30), order='F'), xyz1[:,1].reshape((30, 30), order='F'),  Dpred[:,itime,0].reshape((30, 30), order='F'), 30)
dat1 = ax[1].contourf(xyz2[:,0].reshape((30, 30), order='F'), xyz2[:,1].reshape((30, 30), order='F'),  Dpred[:,itime,1].reshape((30, 30), order='F'), 30)

# %%
itime = 0
fig, ax = plt.subplots(1,2, figsize = (10, 4))
ax[0].hist(Dpred1[:,itime])
ax[1].hist(Dpred2[:,itime])
# Out:
# (array([   5.,   20.,   61.,  103.,  164.,  215.,  189.,  104.,   35.,    4.]),
#  array([  5.40493730e-10,   6.04077120e-10,   6.67660509e-10,
#           7.31243899e-10,   7.94827289e-10,   8.58410679e-10,
#           9.21994068e-10,   9.85577458e-10,   1.04916085e-09,
#           1.11274424e-09,   1.17632763e-09]),
#  <a list of 10 Patch objects>)

# %%
from JSAnimation import IPython_display
from matplotlib import animation
fig, ax = plt.subplots(1,2, figsize = (12, 5))
for i in range(2):
    ax[i].set_xlabel('x (m)', fontsize = 16)
    ax[i].set_ylabel('y (m)', fontsize = 16)

def animate(itime):
    frame1 = ax[0].contourf(xyz1[:,0].reshape((30, 30), order='F'), xyz1[:,1].reshape((30, 30), order='F'),  Dpred[:,itime,0].reshape((30, 30), order='F'), 30)
    frame2 = ax[1].contourf(xyz2[:,0].reshape((30, 30), order='F'), xyz2[:,1].reshape((30, 30), order='F'),  Dpred[:,itime,1].reshape((30, 30), order='F'), 30)
#     cb1 = plt.colorbar(frame1, ax = ax[0])
#     cb2 = plt.colorbar(frame2, ax = ax[1])    
    return frame1, frame2
animation.FuncAnimation(fig, animate, frames=31, interval=40, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgYLTJQJSYQZODWNRF">
#     <br>
#     <input id="_anim_sliderYLTJQJSYQZODWNRF" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animYLTJQJSYQZODWNRF.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animYLTJQJSYQZODWNRF.slower()">&#8211;</button>
#     <button onclick="animYLTJQJSYQZODWNRF.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animYLTJQJSYQZODWNRF.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animYLTJQJSYQZODWNRF.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animYLTJQJSYQZODWNRF.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animYLTJQJSYQZODWNRF.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animYLTJQJSYQZODWNRF.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animYLTJQJSYQZODWNRF.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animYLTJQJSYQZODWNRF.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectYLTJQJSYQZODWNRF" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgYLTJQJSYQZODWNRF";
#     var slider_id = "_anim_sliderYLTJQJSYQZODWNRF";
#     var loop_select_id = "_anim_loop_selectYLTJQJSYQZODWNRF";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAIABJREFUeJzsvX/MZGlV77uqxRnMMKch0HS/70z12S9M0zMTEfXM4I+I\
# 9BUGQ3IUUUIAA4MaPJxRbkL0MgoxTrhRh3hiwBgVlKh4jIA3keHGXC5BaWI0cThXRQSERrrsYrp7\
# mAGn0SbMODN9/3jfp961V631PGs9P/auemt9kkpV7dr7eZ69a9eu57vXr8mVK1eugOM4juM4juM4\
# jtOcQ2MPwHEcx3Ecx3EcZ1NwAeY4juM4juM4jjMQLsAcx3Ecx3Ecx3EGwgWY4ziO4ziO4zjOQLgA\
# cxzHcRzHcRzHGQgXYI7jOI7jOI7jOAPhAsxxHMdxHMdxHGcgXIA5juM4juM4juMMhAswx3Ecx3Ec\
# x3GcgXAB5jiO4ziO4ziOMxAuwBzHcRzHcRzHcQbCBZjjOI7jOI7jOM5AuABzHMdxHMdxHMcZCBdg\
# juM4juM4juM4A+ECzHEcx3Ecx3EcZyBcgDmO4ziO4ziO4wyECzDHcRzHcRzHcZyBcAHmOI7jOI7j\
# OI4zEC7AHMdxHMdxHMdxBsIFmOM4juM4juM4zkC4AHMcx3Ecx3EcxxkIF2CO4ziO4ziO4zgD4QLM\
# cRzHcRzHcRxnIFyAOY7jOI7jOI7jDIQLMMdxHMdxHMdxnIFwAeY4juM4juM4jjMQLsAcx3Ecx3Ec\
# x3EGwgWY4ziO4ziO4zjOQLgAcxzHcRzHcRzHGQgXYI7jOI7jOI7jOAPhAsxxHMdxHMdxHGcgXIA5\
# juM4juM4juMMhAswx3Ecx3Ecx3GcgXAB5jiO4ziO4ziOMxAuwBzHcRzHcRzHcQbiCWMPwLExmdwE\
# AP809jAcx3HMPP/5z4fTp0+PPYxBmTztFMCXPzb2MBzHcbJ4znOeA3//938/9jAOHJMrV65cGXsQ\
# jp7JZAIAnzNudWJ50dOY1R7MGBAH17bE5bsArrlr/33HrKNdFmB217R9KX94F8Cr7yrvY8YsU7R5\
# uLuoan561Vz8bP7IdPH66//n/4An/sLPqtqU2t2GC+rtA+dhy7yNtq/773oXfNtd/zWr/cB52C7c\
# vr9/4Zhfmh3bXTAzNBbOOW6bM5Ht8G+li6wX2j1D3tPXsW0BAB6cwKb95UwmE4CfbbTPNwnLb4hs\
# 83lh+T13AbzkLnH7Qycvq4f1+GevUa8b62d6VL5GxZjfv/tbevxXfwkO/R9vYdexjNGy7wE89h3h\
# RzKF/XXmsH/NPUt+jKn9kfbl0MnLi3GEMYQ+O2ZMs71+w1jCOOb3T5f6iB0T0/f/e3cB/Nhd+vVr\
# I/0eAAA+Q95Lv7fADbC7P8+7K97OP0faoPfXY9dvjkfvN26g4djGXbeHwC1gm8qDYBNKKUra6pTL\
# Up9phFdgxrQzU24r9a/pw0LYdmbr99LsmFqESWARZbn+x0SdlSCkJCGWI+q24TwAAOT+RZWKrhjT\
# q+Ywf2QKh7uLuyKsA5sIA1g+ZwD2fxdnmGV4G+497f/EXjuWseH2at3k2XRSE8HPAy/CYpPNQKH4\
# wutbhVgN8RW2DaIl1Rc3Rsv+psYpia+acPuSIxo7mMEMOpjCHOYwhR2YwVnodo8nxI/n2nIDyL+L\
# m2BZPLXmRuiLsHDN1fKEo/33TQSZUwMXYBvBGbCpEyWlAq4DgPvI+9T6Ejm7N8vYRtquy2xLQ0bb\
# wYpSKsQAAP7TN1yCo0hYYevYEOQILb6d81nbtRRdFFaEAdQVYtx6sfcziAuu2GdOfVLiS2Ig8aXd\
# NmZRKRFfVrT7lzOmlPiaw3QhdgLU+mWBCjFq/bJARdjGEkSY5nen+Y1p4EQYgN0aBrAsyABclK0I\
# LsA2GWwF096ZrmU16/aerz2VZ+0KNNCVWczQ62851V/eDTmQPjEhNn9kqrJYXXPqv/Tec9vERFmJ\
# gNqG81UEEBVfx049S7VdK/Fldq/s0OsZ8zk+5zTbddCHvgeQLXE5VjBneLAVTDMx/L5TzYbCIQmf\
# WuJrenQO5777eUXbW8kROhbL0kS5P+KxhfQ+BStYWD+IMDgKSasiQIb76beesq3fgpgVzMqRU3Xa\
# oSIMoEyIYYIocyE2Kh4DtmbkxYAFIrFgKQFWW3jR17FlHKsivDi6xPs9cqxTi/igDLj+UgKMiqec\
# uKwSV0GKVRDRdqSYC4mxBNhSPJjErHAg3fIiep5cmh3b7yc8c7FgFO6z/+UxYCL/DADPTKxjtX5Z\
# JpaVrV851LZ8aQSDtv8hXAklS5N1PwB46xe+/nExYIEZGcccpr14sBgl8X85VItFqyXAKJwLYywG\
# jJLKuVYixlQC7DMA8L9t3HV7CFyArRnVBViK1sKrAxurLLwwXeI92JNlqCflCXC/MQEWhBO1QllF\
# mEWASYKJiiWNMIqJr0BKhI1pAcNWRfV3PlMOoOu/jZ2LS0lBwrNGhFH+LxdgLGFCFhNgWHzVvGMf\
# SdiRK8BiQkaawGvEVxATQ7nEDSG6MLH9yhWTnACLia9ArghrndzEyugirFSABVoIsaQAC4N3AdYC\
# F2BrRpkAA1ArmJ

# %%
# np.save('../bzobs', dobs)
# dmis = DataMisfit.l2_DataMisfit(survey)

# %%
mesh.getEdgeInnerProductDeriv??
