# %%
from SimPEG import *
import simpegEM as EM
from simpegem1d import Utils1D
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png')
matplotlib.rcParams['savefig.dpi'] = 100

# %%
matplotlib.rcParams.update({'font.size': 16})

# %%
meshType = 'CYL'
cs, ncx, ncz, npad = 20., 25, 30, 20
hx = [(cs,ncx), (cs,npad,1.3)]
hz = [(cs,npad,-1.4), (cs,ncz), (cs,npad,1.4)]
mesh = Mesh.CylMesh([hx,1,hz], '00C')

# %%
active = mesh.vectorCCz<0.
layer1 = (mesh.vectorCCz<0.) & (mesh.vectorCCz>=-60.)
layer2 = (mesh.vectorCCz<-60) & (mesh.vectorCCz>=-160.)
actMap = Maps.ActiveCells(mesh, active, np.log(1e-8), nC=mesh.nCz)
mapping = Maps.ExpMap(mesh) * Maps.Vertical1DMap(mesh) * actMap

# %%
sig_half = 1e-3
sig_air = 1e-8
sig_layer1 = 1./300
sig_layer2 = 1./5.
sigma = np.ones(mesh.nCz)*sig_air
sigma_half = sigma.copy()
sigma[active] = sig_half
sigma[layer1] = sig_layer1
sigma[layer2] = sig_layer2
sigma_half[active] = sig_half
sigma_half[layer1] = sig_layer1
sigma_half[layer2] = 1./500.
mtrue = np.log(sigma[active])

# %%
sig_sea = sigma[active]
sig_half = sigma_half[active]

# %%
fig, ax = plt.subplots(1,1, figsize = (3, 5))
ax.plot(1000, 1000, 'k')
ax.plot(1000, 1000, 'b')
ax.legend(('With intrusion', 'Without intrusion'), loc=4,fontsize = 10)
Utils1D.plotLayer(sig_half, mesh.vectorCCz[active], ax = ax, **{'color':'b'})
Utils1D.plotLayer(sig_sea, mesh.vectorCCz[active], showlayers=True, ax = ax)
ax.set_ylim(-400., 0.)
ax.text(2e-3, -110, 'Brine saturated layer',fontsize = 12)
ax.text(2e-3, -200, 'Basement',fontsize = 12)

# %%
prb = EM.TDEM.ProblemTDEM_b(mesh, mapping=mapping, verbose=False)

# %%
prb.Solver = SolverLU
prb.timeSteps = [(1e-4/10, 15), (1e-4/10, 15), (1e-2/10, 15), (1e1/10, 15)]

# %%
time = np.logspace(-4, -1, 51)

# %%
x = np.linspace(0, 250, 26)
xyz_rx = Utils.ndgrid(x, np.r_[0.], np.r_[0.])

# %%
rx = EM.TDEM.RxTDEM(xyz_rx, time, 'bz')
tx = EM.TDEM.TxTDEM(np.array([0., 0., 0.]), 'CircularLoop_MVP', [rx])
tx.radius = 250.
survey = EM.TDEM.SurveyTDEM([tx])
if prb.ispaired:
    prb.unpair()
if survey.ispaired:
    survey.unpair()
prb.pair(survey)

# %%
bz_sea = survey.dpred(np.log(sig_sea))
# Out:
# ### SolverWarning ###: Accuracy on solve is above tolerance: 4.834000e-06 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 4.796762e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 4.767665e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 3.487505e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 1.976027e-05 > 1.000000e-06
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 4.834000e-06 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 4.796762e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 4.767665e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 3.487505e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 1.976027e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# ### SolverWarning ###: Accuracy on solve is above tolerance: 6.784015e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 3.149547e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 2.559992e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 2.501234e-05 > 1.000000e-06
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 6.784015e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 3.149547e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 2.559992e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 2.501234e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)

# %%
bz_half = survey.dpred(np.log(sig_half))
# Out:
# ### SolverWarning ###: Accuracy on solve is above tolerance: 1.482461e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 1.591907e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 1.448632e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 2.052125e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 2.848829e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 2.456855e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 2.549575e-05 > 1.000000e-06
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 1.482461e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 1.591907e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 1.448632e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 2.052125e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 2.848829e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 2.456855e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 2.549575e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# ### SolverWarning ###: Accuracy on solve is above tolerance: 3.094109e-05 > 1.000000e-06
# ### SolverWarning ###: Accuracy on solve is above tolerance: 1.459879e-05 > 1.000000e-06
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 3.094109e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\SEOGI\simpeg\SimPEG\Utils\SolverUtils.py:13: RuntimeWarning: ### SolverWarning ###: Accuracy on solve is above tolerance: 1.459879e-05 > 1.000000e-06
#   warnings.warn(msg, RuntimeWarning)

# %%
Bz_sea = bz_sea.reshape((x.size, time.size), order='F')
Bz_half = bz_half.reshape((x.size, time.size), order='F')

# %%
TimeX = Utils.ndgrid(x, time)
X = TimeX[:,0].reshape((x.size, time.size), order='F')
Time = TimeX[:,1].reshape((x.size, time.size), order='F')

# %%
print ('$10^{%3.2f}$') % (3.0)
# Out:
# $10^{3.00}$

# %%
test = (np.arange(7)*0.5-4).tolist()
dummy = []
for itest in test:
    dummy.append('10$^{'+str(itest)+'}$')

# %%
print dummy
# Out:
# ['10$^{-4.0}$', '10$^{-3.5}$', '10$^{-3.0}$', '10$^{-2.5}$', '10$^{-2.0}$', '10$^{-1.5}$', '10$^{-1.0}$']

# %%
fig, ax = plt.subplots(1,1, figsize = (8,6))
dat = ax.contourf(X, np.log10(Time), (Bz_sea/Bz_half), 100, cmap = cm.RdPu) #, vmin=1, vmax=1.14, clim=(1, 1.14))
ax.set_xlabel('Distance (m)', fontsize = 16)
ax.set_ylabel('Time (s)', fontsize = 16)
ax.set_yticklabels(dummy)
cb = colorbar(dat, ax = ax)
levels = np.r_[100., 200., 350.]
CS = ax.contour(X, np.log10(Time), (Bz_sea/Bz_half), levels, colors='k')
ax.clabel(CS, inline=1, fmt = '%3.1f')
# cb = colorbar(dat, ax = ax, format='%5.2f', ticks=np.linspace(1, 1.14, 5))
cb.set_label('Amplitude ratio', fontsize = 14)
fig.savefig('figures/ampratio_time.png', dpi=200)

# %%
fig, ax = plt.subplots(1,1, figsize = (8,6))
dat = ax.contourf(X, np.log10(Time), (Bz_sea), 100) #, vmin=1, vmax=1.14, clim=(1, 1.14))
ax.set_xlabel('Distance (m)', fontsize = 16)
ax.set_ylabel('Time (s)', fontsize = 16)
ax.set_yticklabels(dummy)
cb = colorbar(dat, ax = ax)
# cb = colorbar(dat, ax = ax, format='%5.2f', ticks=np.linspace(1, 1.14, 5))
cb.set_label('bz (T)', fontsize = 14)

# %%
fig, ax = plt.subplots(1,1, figsize = (8,6))
dat = ax.contourf(X, np.log10(Time), (Bz_half), 100) #, vmin=1, vmax=1.14, clim=(1, 1.14))
ax.set_xlabel('Distance (m)', fontsize = 16)
ax.set_ylabel('Time (s)', fontsize = 16)
ax.set_yticklabels(dummy)
cb = colorbar(dat, ax = ax)
# cb = colorbar(dat, ax = ax, format='%5.2f', ticks=np.linspace(1, 1.14, 5))
cb.set_label('Amplitude ratio', fontsize = 14)

# %% [markdown]
# Discussions:
#
# - Possible time range: 1e-3-1s
